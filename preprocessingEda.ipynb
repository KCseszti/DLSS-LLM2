# %%
from google.colab import drive
import json
import pandas as pd
import re, time, requests, pandas as pd
from dateutil.rrule import rrule, WEEKLY
from datetime import datetime
import re
import nltk
from nltk.corpus import stopwords

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/DLSS Project/hot100_2000_2025_raw.json'
file_path_2= '/content/drive/MyDrive/DLSS Project/NEW_genius_lyrics_raw.json'
billboard_df = pd.read_json(file_path, lines=False)
genius_df = pd.read_json(file_path_2, lines=False)

# %%
# Correcting the date format after opening the json file
billboard_df["chart_date"] = pd.to_datetime(billboard_df["chart_date"], unit="ms", errors="coerce")
billboard_df["chart_date"] = billboard_df["chart_date"].dt.strftime("%Y-%m-%d")
billboard_df.head()
# Out:
#    chart_date  rank                     title  \
# 0  2000-01-08     1                    Smooth
# 1  2000-01-08     2               Back At One
# 2  2000-01-08     3  I Wanna Love You Forever
# 3  2000-01-08     4      My Love Is Your Love
# 4  2000-01-08     5                  Hot Boyz
#
#                                               artist  last_week  peak  \
# 0                         SantanaFeaturingRob Thomas        1.0     1
# 1                                     Brian McKnight        2.0     2
# 2                                    Jessica Simpson        3.0     3
# 3                                    Whitney Houston        4.0     4
# 4  Missy "Misdemeanor" Elliott FeaturingNas,Eve&Q...        7.0     5
#
#    weeks_on_chart
# 0              24
# 1              20
# 2              13
# 3              19
# 4               7

# %%
# Clean the raw dataset
def clean_artist_name(name):
    # space around &
    name = re.sub(r'\s*&\s*', ' & ', name)
    # space around "and"
    name = re.sub(r'\s*(and)\s*', r' and ', name, flags=re.IGNORECASE)
    # space around "Featuring"
    name = re.sub(r'\s*(featuring)\s*', r' Featuring ', name, flags=re.IGNORECASE)
    # space around "Feat"
    name = re.sub(r'\s*(feat\.)\s*', r' Feat. ', name, flags=re.IGNORECASE)
    # space around "Presents"
    name = re.sub(r'\s*(presents)\s*', r' Presents ', name, flags=re.IGNORECASE)
    # space around "With"
    name = re.sub(r'\s*(with)\s*', r' With ', name, flags=re.IGNORECASE)
    # space around ","
    name = re.sub(r'\s*,\s*', ', ', name)
    # remove extra spaces
    name = re.sub(r'\s+', ' ', name).strip()

    return name

billboard_df["artist"] = billboard_df["artist"].apply(clean_artist_name)

## later added adjustment based on the first results - Ariana Grande
billboard_df["artist"] = billboard_df["artist"].str.replace(r"Gr\s*and\s*e", "Grande", regex=True)

billboard_df
# Out:
#         chart_date  rank                            title  \
# 0       2000-01-08     1                           Smooth
# 1       2000-01-08     2                      Back At One
# 2       2000-01-08     3         I Wanna Love You Forever
# 3       2000-01-08     4             My Love Is Your Love
# 4       2000-01-08     5                         Hot Boyz
# ...            ...   ...                              ...
# 133595  2025-08-09    96                         Madeline
# 133596  2025-08-09    97                         Mommanem
# 133597  2025-08-09    98                River Washed Hair
# 133598  2025-08-09    99  Don't Tap That Glass / Tweakin'
# 133599  2025-08-09   100                        Tu Sancho
#
#                                                    artist  last_week  peak  \
# 0                            Santana Featuring Rob Thomas        1.0     1
# 1                                          Brian McKnight        2.0     2
# 2                                         Jessica Simpson        3.0     3
# 3                                         Whitney Houston        4.0     4
# 4       Missy "Misdemeanor" Elliott Featuring Nas, Eve...        7.0     5
# ...                                                   ...        ...   ...
# 133595                Zach Bryan Featuring Gabriella Rose       62.0    62
# 133596                                 Tyler, the Creator       54.0    54
# 133597                                         Zach Bryan       90.0    53
# 133598                                 Tyler, the Creator       56.0    56
# 133599                                      Fuerza Regida        NaN    65
#
#         weeks_on_chart
# 0                   24
# 1                   20
# 2                   13
# 3                   19
# 4                    7
# ...                ...
# 133595               2
# 133596               2
# 133597               4
# 133598               2
# 133599               7
#
# [133600 rows x 7 columns]

# %%
# Filter dataset by timerange - 2018-2024
billboard_df = billboard_df.copy()
billboard_df["chart_date"] = pd.to_datetime(billboard_df["chart_date"]).dt.date

mask = (billboard_df["chart_date"] >= pd.to_datetime("2018-01-01").date()) & \
       (billboard_df["chart_date"] <= pd.to_datetime("2024-12-31").date())
billboard_2018_2024 = billboard_df[mask].copy()

billboard_2018_2024
# Out:
#         chart_date  rank                       title  \
# 93900   2018-01-06     1                     Perfect
# 93901   2018-01-06     2                    Rockstar
# 93902   2018-01-06     3                      Havana
# 93903   2018-01-06     4                    No Limit
# 93904   2018-01-06     5                     Thunder
# ...            ...   ...                         ...
# 130395  2024-12-28    96                      Gloria
# 130396  2024-12-28    97                  Diet Pepsi
# 130397  2024-12-28    98                     Disease
# 130398  2024-12-28    99  Shake Dat Ass (Twerk Song)
# 130399  2024-12-28   100                  St. Chroma
#
#                                             artist  last_week  peak  \
# 93900                                   Ed Sheeran        1.0     1
# 93901              Post Malone Featuring 21 Savage        2.0     1
# 93902          Camila Cabello Featuring Young Thug        3.0     2
# 93903        G-Eazy Featuring A$AP Rocky & Cardi B        5.0     4
# 93904                              Imagine Dragons        6.0     4
# ...                                            ...        ...   ...
# 130395                        Kendrick Lamar & SZA       76.0    27
# 130396                                 Addison Rae        NaN    54
# 130397                                   Lady Gaga        NaN    27
# 130398                                BossMan Dlow        NaN    54
# 130399  Tyler, the Creator Featuring Daniel Caesar       95.0     7
#
#         weeks_on_chart
# 93900               18
# 93901               15
# 93902               20
# 93903               16
# 93904               35
# ...                ...
# 130395               4
# 130396              13
# 130397               7
# 130398              13
# 130399               8
#
# [36500 rows x 7 columns]

# %% [markdown]
# <h2>Preparation for cleaning the lyrics</h2>

# %%
# Remove duplicate entries from billboard
unique_songs_df = billboard_2018_2024[["title", "artist"]].drop_duplicates().reset_index(drop=True)
unique_songs_df
# Out:
#                    title                                 artist
# 0                Perfect                             Ed Sheeran
# 1               Rockstar        Post Malone Featuring 21 Savage
# 2                 Havana    Camila Cabello Featuring Young Thug
# 3               No Limit  G-Eazy Featuring A$AP Rocky & Cardi B
# 4                Thunder                        Imagine Dragons
# ...                  ...                                    ...
# 4415             El Club                              Bad Bunny
# 4416             Rosones                          Tito Double P
# 4417  Toxic Till The End                                   ROSE
# 4418     White Christmas                        V & Bing Crosby
# 4419              Indigo        Sam Barber Featuring Avery Anna
#
# [4420 rows x 2 columns]

# %%
# Filter genius dataset - just the relevant songs are going to stay
genius_filtered = genius_df.merge(unique_songs_df[["artist", "title"]], on=["artist", "title"], how="inner")
genius_filtered
# Out:
#                                 title                           artist  \
# 0     All I Want For Christmas Is You                     Mariah Carey
# 1                         Bye Bye Bye                           *NSYNC
# 2                        Still D.R.E.     Dr. Dre Featuring Snoop Dogg
# 3               Party Up (Up In Here)                              DMX
# 4                    The Next Episode     Dr. Dre Featuring Snoop Dogg
# ...                               ...                              ...
# 4415                          El Club                        Bad Bunny
# 4416                          Rosones                    Tito Double P
# 4417               Toxic Till The End                             ROSE
# 4418                  White Christmas                  V & Bing Crosby
# 4419                           Indigo  Sam Barber Featuring Avery Anna
#
#        genius_id language primary_tag  \
# 0       204233.0       en         R&B
# 1       115478.0       en         Pop
# 2      7701008.0       en   Non-Music
# 3         4402.0       en         Rap
# 4      7701008.0       en   Non-Music
# ...          ...      ...         ...
# 4415  11180508.0       es         Pop
# 4416  11098618.0       es         Pop
# 4417  11112065.0       en         Pop
# 4418  11199532.0       es         Pop
# 4419  10987162.0       en     Country
#
#                                                    tags  \
# 0     [R&B, Pop, USA, In English, Soul Pop, Soul, Po...
# 1     [Pop, Alternative Dance, Soundtrack, USA, In E...
# 2     [Non-Music, R&B, Rap, In English, USA, America...
# 3     [Rap, Hip-Hop, New York Rap, In English, USA, ...
# 4     [Non-Music, R&B, Rap, In English, USA, America...
# ...                                                 ...
# 4415  [Pop, Deep House, Latin Pop, House, Latin Urba...
# 4416  [Pop, Cover, En Español, México, Latin Music, ...
# 4417  [Pop, NZ Pop, K-Pop (케이팝), In English, Genius ...
# 4418                       [Pop, Traducción Al Español]
# 4419                         [Country, USA, In English]
#
#                                              genius_url release_date  \
# 0     https://genius.com/Mariah-carey-all-i-want-for...   1994-10-29
# 1           https://genius.com/Nsync-bye-bye-bye-lyrics   2000-01-11
# 2     https://genius.com/Dr-dre-snoop-dogg-eminem-ma...   2022-02-13
# 3     https://genius.com/Dmx-party-up-up-in-here-lyrics   1999-12-21
# 4     https://genius.com/Dr-dre-snoop-dogg-eminem-ma...   2022-02-13
# ...                                                 ...          ...
# 4415        https://genius.com/Bad-bunny-el-club-lyrics   2024-12-05
# 4416    https://genius.com/Tito-double-p-rosones-lyrics   2024-12-05
# 4417  https://genius.com/Rose-toxic-till-the-end-lyrics   2024-12-06
# 4418  https://genius.com/Genius-traducciones-al-espa...   2024-12-06
# 4419        https://genius.com/Sam-barber-indigo-lyrics   2024-11-01
#
#                               album  \
# 0                     Greatest Hits
# 1              The Essential *NSYNC
# 2         Super Bowl Halftime Shows
# 3          Verzuz: DMX x Snoop Dogg
# 4         Super Bowl Halftime Shows
# ...                             ...
# 4415           DeBÍ TiRAR MáS FOToS
# 4416                           None
# 4417  rosie (vampirehollie edition)
# 4418                           None
# 4419                  Restless Mind
#
#                                                  lyrics
# 0     185 Contributors\nTranslations\nEspañol\nTürkç...
# 1     94 Contributors\nTranslations\nDeutsch\nEspaño...
# 2     43 Contributors\nSuper Bowl LVI Halftime Show ...
# 3     138 Contributors\nParty Up (Up in Here) Lyrics...
# 4     43 Contributors\nSuper Bowl LVI Halftime Show ...
# ...                                                 ...
# 4415  28 Contributors\nTranslations\nEnglish\nDeutsc...
# 4416  8 Contributors\nTranslations\nEnglish\nROSONES...
# 4417  62 Contributors\nTranslations\nالعربية\nItalia...
# 4418  1 Contributor\nTranslations\nEnglish\nV & Bing...
# 4419  15 Contributors\nIndigo Lyrics\n[Verse 1: Sam ...
#
# [4420 rows x 10 columns]

# %%
# Remove the non-english songs
genius_filtered_en = genius_filtered[genius_filtered["language"] == "en"].copy()
genius_filtered_en
# Out:
#                                 title                           artist  \
# 0     All I Want For Christmas Is You                     Mariah Carey
# 1                         Bye Bye Bye                           *NSYNC
# 2                        Still D.R.E.     Dr. Dre Featuring Snoop Dogg
# 3               Party Up (Up In Here)                              DMX
# 4                    The Next Episode     Dr. Dre Featuring Snoop Dogg
# ...                               ...                              ...
# 4412                         KTM Drip                       Juice WRLD
# 4413                           Cuffed                       Juice WRLD
# 4414                     Winter Ahead             V With Park Hyo Shin
# 4417               Toxic Till The End                             ROSE
# 4419                           Indigo  Sam Barber Featuring Avery Anna
#
#        genius_id language primary_tag  \
# 0       204233.0       en         R&B
# 1       115478.0       en         Pop
# 2      7701008.0       en   Non-Music
# 3         4402.0       en         Rap
# 4      7701008.0       en   Non-Music
# ...          ...      ...         ...
# 4412   6766139.0       en         Rap
# 4413   6539310.0       en         Rap
# 4414  11141687.0       en         Pop
# 4417  11112065.0       en         Pop
# 4419  10987162.0       en     Country
#
#                                                    tags  \
# 0     [R&B, Pop, USA, In English, Soul Pop, Soul, Po...
# 1     [Pop, Alternative Dance, Soundtrack, USA, In E...
# 2     [Non-Music, R&B, Rap, In English, USA, America...
# 3     [Rap, Hip-Hop, New York Rap, In English, USA, ...
# 4     [Non-Music, R&B, Rap, In English, USA, America...
# ...                                                 ...
# 4412  [Rap, Midwest Rap, Alternative, Alternative Ra...
# 4413  [Rap, USA, Leak, Hip-Hop, Dark Trap, In Englis...
# 4414  [Pop, K-Ballad, In English, Jazz, Duet, South ...
# 4417  [Pop, NZ Pop, K-Pop (케이팝), In English, Genius ...
# 4419                         [Country, USA, In English]
#
#                                              genius_url release_date  \
# 0     https://genius.com/Mariah-carey-all-i-want-for...   1994-10-29
# 1           https://genius.com/Nsync-bye-bye-bye-lyrics   2000-01-11
# 2     https://genius.com/Dr-dre-snoop-dogg-eminem-ma...   2022-02-13
# 3     https://genius.com/Dmx-party-up-up-in-here-lyrics   1999-12-21
# 4     https://genius.com/Dr-dre-snoop-dogg-eminem-ma...   2022-02-13
# ...                                                 ...          ...
# 4412      https://genius.com/Juice-wrld-ktm-drip-lyrics   2024-11-29
# 4413        https://genius.com/Juice-wrld-cuffed-lyrics   2024-11-29
# 4414  https://genius.com/V-and-park-hyo-shin-winter-...   2024-11-29
# 4417  https://genius.com/Rose-toxic-till-the-end-lyrics   2024-12-06
# 4419        https://genius.com/Sam-barber-indigo-lyrics   2024-11-01
#
#                                  album  \
# 0                        Greatest Hits
# 1                 The Essential *NSYNC
# 2            Super Bowl Halftime Shows
# 3             Verzuz: DMX x Snoop Dogg
# 4            Super Bowl Halftime Shows
# ...                                ...
# 4412     The Party Never Ends (Deluxe)
# 4413     The Party Never Ends (Deluxe)
# 4414  Winter Ahead (Silent Carol Ver.)
# 4417     rosie (vampirehollie edition)
# 4419                     Restless Mind
#
#                                                  lyrics
# 0     185 Contributors\nTranslations\nEspañol\nTürkç...
# 1     94 Contributors\nTranslations\nDeutsch\nEspaño...
# 2     43 Contributors\nSuper Bowl LVI Halftime Show ...
# 3     138 Contributors\nParty Up (Up in Here) Lyrics...
# 4     43 Contributors\nSuper Bowl LVI Halftime Show ...
# ...                                                 ...
# 4412  149 Contributors\nTranslations\nУкраїнська\nРу...
# 4413  78 Contributors\nCuffed Lyrics\nOn “Cuffed,“ J...
# 4414  20 Contributors\nTranslations\nEspañol\n한국어 (K...
# 4417  62 Contributors\nTranslations\nالعربية\nItalia...
# 4419  15 Contributors\nIndigo Lyrics\n[Verse 1: Sam ...
#
# [3662 rows x 10 columns]

# %%
## Checking the unique primary_tags (aka genre)
# List of unique tags
unique_tags = genius_filtered_en["primary_tag"].dropna().unique()
print(unique_tags)

# Count of tags
tag_counts = genius_filtered_en["primary_tag"].value_counts(dropna=True)
print(tag_counts)
# Out:
# ['R&B' 'Pop' 'Non-Music' 'Rap' 'Rock' 'Electronic' 'Country'
#  '#FlipTheSwitchChallenge' 'rage' 'Chicago drill' 'pop' 'drill' 'Funk'
#  'EDM' 'Hip-Hop' 'trap' 'hyphy']
# primary_tag
# Rap                        1218
# Pop                         662
# Country                     467
# Non-Music                   466
# R&B                         423
# Electronic                  224
# Rock                        190
# Chicago drill                 2
# #FlipTheSwitchChallenge       1
# rage                          1
# pop                           1
# drill                         1
# Funk                          1
# EDM                           1
# Hip-Hop                       1
# trap                          1
# hyphy                         1
# Name: count, dtype: int64

# %%
# Remove primary_tags that are "Non-Music"
genius_filtered_en = genius_filtered_en[genius_filtered_en["primary_tag"] != "Non-Music"].copy()

# Normalize the rest of the tags - lowercase
genius_filtered_en["primary_tag"] = genius_filtered_en["primary_tag"].astype(str).str.lower()
print(genius_filtered_en["primary_tag"].unique())
# Out:
# ['r&b' 'pop' 'rap' 'rock' 'electronic' 'country' '#fliptheswitchchallenge'
#  'rage' 'chicago drill' 'drill' 'funk' 'edm' 'hip-hop' 'trap' 'hyphy'
#  'none']

# %%
# Primary_tag "none" - 1 case, Eminem -> rap
genius_filtered_en["primary_tag"] = genius_filtered_en["primary_tag"].replace("none", "rap")

# %% [markdown]
# <h2>Cleaning the lyrics</h2>

# %%
nltk.download('stopwords')

# Clean lyrics w regex function
def clean_lyrics(text: str) -> str:
    if not isinstance(text, str) or not text.strip():
        return text

    # Remove texts until the first found - Intro/Verse/Chorus/Bridge/Pre-Chorus/Hook/Refrain/Outro
    section_pat = r"\[(?:.*?(?:Intro|Verse|Chorus|Bridge|Pre[- ]?Chorus|Hook|Refrain|Outro).*?)\]"
    m = re.search(section_pat, text, flags=re.IGNORECASE | re.DOTALL)
    if m:
        text = text[m.start():]
    else:
        # Without [] blocks, start with removing the "X Contributors ... Read More" blocks
        text = re.sub(r"(?is)^\s*\d+\s+Contributors.*?(Read\s*More\s*)?\n+", "", text, count=1)
        text = re.sub(r"(?is)^\s*.*?lyrics\s*\n+", "", text, count=1)

    # Remove all of the [ ... ] and ( ... ) blocks (eg. [Verse 1], [Chorus], ...etc.)
    text = re.sub(r"\[.*?\]", "", text, flags=re.S)
    text = re.sub(r"\(.*?\)", "", text, flags=re.S)
    text = re.sub(r"\[.*?Intro.*?\]", "", text, flags=re.IGNORECASE)

    # Remove empty rowes/whitespaces
    text = re.sub(r"[ \t]+\n", "\n", text)
    text = re.sub(r"\n{3,}", "\n\n", text)
    text = text.strip()

    return text

# Run function - clean lyrics
genius_filtered_en.loc[:, "lyrics_clean"] = genius_filtered_en["lyrics"].apply(clean_lyrics)


# Remove stopwords
stop_words = set(stopwords.words("english"))
# extra words
extra_fillers = {"oh", "ooh", "yeah", "na", "la", "ha", "woo", "du", "lol", "uh", "hey", "ah"}
stop_words = stop_words.union(extra_fillers)

# Remove stopwords function
def remove_stopwords(text: str) -> str:
    if not isinstance(text, str) or not text.strip():
        return text

    # words into lowercase
    words = re.findall(r"\b\w+\b", text.lower())

    # filter stopwords
    filtered = [w for w in words if w not in stop_words]

    return " ".join(filtered)

# Run function - remove stopwords
genius_filtered_en.loc[:, "lyrics_clean"] = genius_filtered_en["lyrics_clean"].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Just in case - remove rows with empty lyrics (just 1 case)
genius_filtered_en["lyrics_clean"] = genius_filtered_en["lyrics_clean"].replace(r"^\s*$", pd.NA, regex=True)
genius_filtered_en = genius_filtered_en.dropna(subset=["lyrics_clean"])

genius_filtered_en
# Out:
#                                 title                           artist  \
# 0     All I Want For Christmas Is You                     Mariah Carey
# 1                         Bye Bye Bye                           *NSYNC
# 3               Party Up (Up In Here)                              DMX
# 5                       Lose Yourself                           Eminem
# 6                X Gon' Give It To Ya                              DMX
# ...                               ...                              ...
# 4412                         KTM Drip                       Juice WRLD
# 4413                           Cuffed                       Juice WRLD
# 4414                     Winter Ahead             V With Park Hyo Shin
# 4417               Toxic Till The End                             ROSE
# 4419                           Indigo  Sam Barber Featuring Avery Anna
#
#        genius_id language primary_tag  \
# 0       204233.0       en         r&b
# 1       115478.0       en         pop
# 3         4402.0       en         rap
# 5          207.0       en         pop
# 6         3200.0       en         rap
# ...          ...      ...         ...
# 4412   6766139.0       en         rap
# 4413   6539310.0       en         rap
# 4414  11141687.0       en         pop
# 4417  11112065.0       en         pop
# 4419  10987162.0       en     country
#
#                                                    tags  \
# 0     [R&B, Pop, USA, In English, Soul Pop, Soul, Po...
# 1     [Pop, Alternative Dance, Soundtrack, USA, In E...
# 3     [Rap, Hip-Hop, New York Rap, In English, USA, ...
# 5     [Pop, Rap, In English, USA, Pop Rap, Detroit R...
# 6     [Rap, Hip-Hop, New York Rap, In English, USA, ...
# ...                                                 ...
# 4412  [Rap, Midwest Rap, Alternative, Alternative Ra...
# 4413  [Rap, USA, Leak, Hip-Hop, Dark Trap, In Englis...
# 4414  [Pop, K-Ballad, In English, Jazz, Duet, South ...
# 4417  [Pop, NZ Pop, K-Pop (케이팝), In English, Genius ...
# 4419                         [Country, USA, In English]
#
#                                              genius_url release_date  \
# 0     https://genius.com/Mariah-carey-all-i-want-for...   1994-10-29
# 1           https://genius.com/Nsync-bye-bye-bye-lyrics   2000-01-11
# 3     https://genius.com/Dmx-party-up-up-in-here-lyrics   1999-12-21
# 5        https://genius.com/Eminem-lose-yourself-lyrics   2002-10-28
# 6     https://genius.com/Dmx-x-gon-give-it-to-ya-lyrics   2003-02-18
# ...                                                 ...          ...
# 4412      https://genius.com/Juice-wrld-ktm-drip-lyrics   2024-11-29
# 4413        https://genius.com/Juice-wrld-cuffed-lyrics   2024-11-29
# 4414  https://genius.com/V-and-park-hyo-shin-winter-...   2024-11-29
# 4417  https://genius.com/Rose-toxic-till-the-end-lyrics   2024-12-06
# 4419        https://genius.com/Sam-barber-indigo-lyrics   2024-11-01
#
#                                  album  \
# 0                        Greatest Hits
# 1                 The Essential *NSYNC
# 3             Verzuz: DMX x Snoop Dogg
# 5                              SHADYXV
# 6             Verzuz: DMX x Snoop Dogg
# ...                                ...
# 4412     The Party Never Ends (Deluxe)
# 4413     The Party Never Ends (Deluxe)
# 4414  Winter Ahead (Silent Carol Ver.)
# 4417     rosie (vampirehollie edition)
# 4419                     Restless Mind
#
#                                                  lyrics  \
# 0     185 Contributors\nTranslations\nEspañol\nTürkç...
# 1     94 Contributors\nTranslations\nDeutsch\nEspaño...
# 3     138 Contributors\nParty Up (Up in Here) Lyrics...
# 5     826 Contributors\nTranslations\nDeutsch\nTürkç...
# 6     161 Contributors\nTranslations\nDeutsch\nX Gon...
# ...                                                 ...
# 4412  149 Contributors\nTranslations\nУкраїнська\nРу...
# 4413  78 Contributors\nCuffed Lyrics\nOn “Cuffed,“ J...
# 4414  20 Contributors\nTranslations\nEspañol\n한국어 (K...
# 4417  62 Contributors\nTranslations\nالعربية\nItalia...
# 4419  15 Contributors\nIndigo Lyrics\n[Verse 1: Sam ...
#
#                                            lyrics_clean
# 0     want lot christmas one thing need care present...
# 1     bye bye bye doin tonight probably gonna start ...
# 3     gon make lose mind gon make go gon make act fo...
# 5     look one shot one opportunity seize everything...
# 6     arf arf get twisted rap shit mine motherfucker...
# ...                                                 ...
# 4412  perc get let fuck hatin outside club drugs kno...
# 4413  hold hold hold hold gon get wild bitch yo ayy ...
# 4414  lie fire safe storms high winter ahead cold we...
# 4417  call us toxic start pretend dark met friends e...
# 4419  know worried night find way tired lyin get day...
#
# [3195 rows x 11 columns]

# %% [markdown]
# <h2>Get date of PEAK from Billboard</h2>

# %%
## Get the dates of the peaks of the songs
# Logic: rank == peak
peak_songs = billboard_2018_2024[billboard_2018_2024["rank"] == billboard_2018_2024["peak"]].copy()

# Sort entries to get the lowest value
peaks_sorted = peak_songs.sort_values(by=["title", "artist", "peak", "chart_date"], ascending=[True,   True,   True,  True])

peak_dates = (peak_songs.sort_values(["title", "artist", "chart_date"]).drop_duplicates(subset=["title", "artist"], keep="first"))

# Keep only the needed columns
peak_dates = (peaks_sorted.drop_duplicates(subset=["title", "artist"], keep="first").rename(columns={"chart_date": "peak_date"})[["title", "artist", "peak", "peak_date"]])
peak_dates
# Out:
#                                                     title  \
# 121026                                         '98 Braves
# 116017                                     'Til You Can't
# 109438                               'Tis The Damn Season
# 125249  (There's No Place Like) Home For The Holidays ...
# 109521  (There's No Place Like) Home For The Holidays ...
# ...                                                   ...
# 111619                                 punchin'.the.clock
# 126922                                    thanK you aIMee
# 111624                                     the.climb.back
# 112175                                    transparentsoul
# 98936                                  whoa (mind in awe)
#
#                                                   artist  peak   peak_date
# 121026                                     Morgan Wallen    27  2023-03-18
# 116017                                      Cody Johnson    18  2022-04-02
# 109438                                      Taylor Swift    39  2020-12-26
# 125249  Perry Como With Mitchell Ayers and His Orchestra    50  2024-01-06
# 109521  Perry Como With Mitchell Ayers and His Orchestra    22  2021-01-02
# ...                                                  ...   ...         ...
# 111619                                           J. Cole    20  2021-05-29
# 126922                                      Taylor Swift    23  2024-05-04
# 111624                                           J. Cole    25  2021-05-29
# 112175                    Willow Featuring Travis Barker    76  2021-07-03
# 98936                                       XXXTENTACION    37  2018-12-22
#
# [4350 rows x 4 columns]

# %%
# Add the peaks to the corresponding songs
genius_with_peak = genius_filtered_en.merge(
    peak_dates[["artist", "title", "peak", "peak_date"]],
    on=["artist", "title"],
    how="left"
)

genius_with_peak

# Save dataset
#genius_with_peak.to_json("genius_cleaned_merged.json")
# Out:
#                                 title                           artist  \
# 0     All I Want For Christmas Is You                     Mariah Carey
# 1                         Bye Bye Bye                           *NSYNC
# 2               Party Up (Up In Here)                              DMX
# 3                       Lose Yourself                           Eminem
# 4                X Gon' Give It To Ya                              DMX
# ...                               ...                              ...
# 3190                         KTM Drip                       Juice WRLD
# 3191                           Cuffed                       Juice WRLD
# 3192                     Winter Ahead             V With Park Hyo Shin
# 3193               Toxic Till The End                             ROSE
# 3194                           Indigo  Sam Barber Featuring Avery Anna
#
#        genius_id language primary_tag  \
# 0       204233.0       en         r&b
# 1       115478.0       en         pop
# 2         4402.0       en         rap
# 3          207.0       en         pop
# 4         3200.0       en         rap
# ...          ...      ...         ...
# 3190   6766139.0       en         rap
# 3191   6539310.0       en         rap
# 3192  11141687.0       en         pop
# 3193  11112065.0       en         pop
# 3194  10987162.0       en     country
#
#                                                    tags  \
# 0     [R&B, Pop, USA, In English, Soul Pop, Soul, Po...
# 1     [Pop, Alternative Dance, Soundtrack, USA, In E...
# 2     [Rap, Hip-Hop, New York Rap, In English, USA, ...
# 3     [Pop, Rap, In English, USA, Pop Rap, Detroit R...
# 4     [Rap, Hip-Hop, New York Rap, In English, USA, ...
# ...                                                 ...
# 3190  [Rap, Midwest Rap, Alternative, Alternative Ra...
# 3191  [Rap, USA, Leak, Hip-Hop, Dark Trap, In Englis...
# 3192  [Pop, K-Ballad, In English, Jazz, Duet, South ...
# 3193  [Pop, NZ Pop, K-Pop (케이팝), In English, Genius ...
# 3194                         [Country, USA, In English]
#
#                                              genius_url release_date  \
# 0     https://genius.com/Mariah-carey-all-i-want-for...   1994-10-29
# 1           https://genius.com/Nsync-bye-bye-bye-lyrics   2000-01-11
# 2     https://genius.com/Dmx-party-up-up-in-here-lyrics   1999-12-21
# 3        https://genius.com/Eminem-lose-yourself-lyrics   2002-10-28
# 4     https://genius.com/Dmx-x-gon-give-it-to-ya-lyrics   2003-02-18
# ...                                                 ...          ...
# 3190      https://genius.com/Juice-wrld-ktm-drip-lyrics   2024-11-29
# 3191        https://genius.com/Juice-wrld-cuffed-lyrics   2024-11-29
# 3192  https://genius.com/V-and-park-hyo-shin-winter-...   2024-11-29
# 3193  https://genius.com/Rose-toxic-till-the-end-lyrics   2024-12-06
# 3194        https://genius.com/Sam-barber-indigo-lyrics   2024-11-01
#
#                                  album  \
# 0                        Greatest Hits
# 1                 The Essential *NSYNC
# 2             Verzuz: DMX x Snoop Dogg
# 3                              SHADYXV
# 4             Verzuz: DMX x Snoop Dogg
# ...                                ...
# 3190     The Party Never Ends (Deluxe)
# 3191     The Party Never Ends (Deluxe)
# 3192  Winter Ahead (Silent Carol Ver.)
# 3193     rosie (vampirehollie edition)
# 3194                     Restless Mind
#
#                                                  lyrics  \
# 0     185 Contributors\nTranslations\nEspañol\nTürkç...
# 1     94 Contributors\nTranslations\nDeutsch\nEspaño...
# 2     138 Contributors\nParty Up (Up in Here) Lyrics...
# 3     826 Contributors\nTranslations\nDeutsch\nTürkç...
# 4     161 Contributors\nTranslations\nDeutsch\nX Gon...
# ...                                                 ...
# 3190  149 Contributors\nTranslations\nУкраїнська\nРу...
# 3191  78 Contributors\nCuffed Lyrics\nOn “Cuffed,“ J...
# 3192  20 Contributors\nTranslations\nEspañol\n한국어 (K...
# 3193  62 Contributors\nTranslations\nالعربية\nItalia...
# 3194  15 Contributors\nIndigo Lyrics\n[Verse 1: Sam ...
#
#                                            lyrics_clean  peak   peak_date
# 0     want lot christmas one thing need care present...   1.0  2019-12-21
# 1     bye bye bye doin tonight probably gonna start ...   NaN         NaN
# 2     gon make lose mind gon make go gon make act fo...   NaN         NaN
# 3     look one shot one opportunity seize everything...   NaN         NaN
# 4     arf arf get twisted rap shit mine motherfucker...  46.0  2021-04-24
# ...                                                 ...   ...         ...
# 3190  perc get let fuck hatin outside club drugs kno...  91.0  2024-12-14
# 3191  hold hold hold hold gon get wild bitch yo ayy ...  95.0  2024-12-14
# 3192  lie fire safe storms high winter ahead cold we...  99.0  2024-12-14
# 3193  call us toxic start pretend dark met friends e...  90.0  2024-12-21
# 3194  know worried night find way tired lyin get day...  65.0  2024-12-28
#
# [3195 rows x 13 columns]

# %%
# Create EDA Dataset

print(len(genius_filtered_en))
print(len(billboard_2018_2024))

test = genius_filtered_en.merge(
    billboard_2018_2024[["artist", "title", "chart_date", "rank"]],
    on=["artist", "title"],
    how="left"
)
print(len(test))
print(len(peak_dates))

test = test.merge(
    peak_dates[["artist", "title", "peak", "peak_date"]],
    on=["artist", "title"],
    how="left"
)
print(len(test))
# Out:
# 3195
# 36500
# 26723
# 4350
# 26723

# %%
# Save EDA dataframe

df_eda.to_json('/content/drive/MyDrive/DLSS Project/eda_data.json', orient="records")
